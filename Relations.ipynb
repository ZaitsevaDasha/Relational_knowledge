# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
from transformers import pipeline
unmasker = pipeline("fill-mask", model='bert-base-uncased')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
import torch
from transformers import BertTokenizer, BertForMaskedLM
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForMaskedLM.from_pretrained(model_name, output_attentions=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Отношения для стран

# %%
preds = unmasker("The greatest country in the world is [MASK].", top_k=150)
countries = [pred['token_str'] for pred in preds]

# %%
corr_countries = []
wrong_countries = []
for country in countries:
    pred = unmasker(f"{country} is the greatest [MASK] in the world.", top_k=1)[0]
    if pred['token_str'] == 'country':
        corr_countries.append(country)
    else:
        wrong_countries.append(country)

# %%
relations = []
for country in tqdm(countries):
    preds = unmasker(f"The [MASK] of {country} is", top_k=15)
    for pred in preds:
        relations.append(pred['sequence'])
# Out:
# 100%|██████████| 150/150 [00:15<00:00,  9.96it/s]

# %% [markdown]
# ## Attention-based подход

# %%
wrong_relations = []
right_relations = []

for relation in relations:
    tokens = tokenizer.tokenize(relation + ' [MASK].')
    indexed_tokens = tokenizer.convert_tokens_to_ids(tokens)
    masked_index = tokens.index("[MASK]")
    tokens_tensor = torch.tensor([indexed_tokens])

    # Generate the attention weights
    with torch.no_grad():
        outputs = model(tokens_tensor)
        attentions = outputs.attentions[-1]

    # Visualize the attention weights
    attention_weights = attentions[0][:, :, masked_index]
    #token_labels = tokens[:len(attention_weights)]

    mean_attentions = torch.mean(attention_weights, 0)

    if mean_attentions[1] < mean_attentions[3]:
        right_relations.append(relation)
    else:
        wrong_relations.append(relation)

# %%
right_relations
# Out:
# ['the peerage of japan is',
#  'the primate of japan is',
#  'the commonwealth of australia is',
#  'the parliament of australia is',
#  'the order of australia is',
#  'the flag of australia is',
#  'the constitution of australia is',
#  'the president of australia is',
#  'the primate of australia is',
#  'the pride of australia is',
#  'the federation of australia is',
#  'the constitution of india is',
#  'the parliament of india is',
#  'the anthem of india is',
#  'the chancellor of india is',
#  'the treasurer of india is',
#  'the primate of india is',
#  'the currency of brazil is',
#  'the anthem of brazil is',
#  'the primate of brazil is',
#  'the economy of brazil is',
#  'the constitution of argentina is',
#  'the currency of argentina is',
#  'the anthem of argentina is',
#  'the government of france is',
#  'the flag of germany is',
#  'the constitution of germany is',
#  'the chancellor of germany is',
#  'the currency of germany is',
#  'the state of germany is',
#  'the parliament of germany is',
#  'the anthem of germany is',
#  'the constitution of mexico is',
#  'the government of mexico is',
#  'the flag of mexico is',
#  'the currency of mexico is',
#  'the nation of mexico is',
#  'the country of mexico is',
#  'the order of canada is',
#  'the constitution of canada is',
#  'the queen of canada is',
#  'the primate of canada is',
#  'the premier of canada is',
#  'the anthem of peru is',
#  'the primate of indonesia is',
#  'the currency of indonesia is',
#  'the kingdom of iran is',
#  'the primate of iran is',
#  'the prince of egypt is',
#  'the kingdom of egypt is',
#  'the constitution of afghanistan is',
#  'the queen of afghanistan is',
#  'the kingdom of afghanistan is',
#  'the primate of afghanistan is',
#  'the constitution of bolivia is',
#  'the economy of bolivia is',
#  'the republic of bolivia is',
#  'the anthem of bolivia is',
#  'the kingdom of italy is',
#  'the peerage of italy is',
#  'the kingdom of spain is',
#  'the crown of spain is',
#  'the kingdom of greece is',
#  'the primate of greece is',
#  'the queen of ghana is',
#  'the primate of ghana is',
#  'the constitution of israel is',
#  'the constitution of vietnam is',
#  'the kingdom of vietnam is',
#  'the republic of vietnam is',
#  'the queen of bangladesh is',
#  'the constitution of poland is',
#  'the anthem of poland is',
#  'the parliament of poland is',
#  'the kingdom of poland is',
#  'the horn of africa is',
#  'the flag of africa is',
#  'the queen of africa is',
#  'the population of africa is',
#  'the union of africa is',
#  'the atlas of africa is',
#  'the church of england is',
#  'the constitution of england is',
#  'the queen of england is',
#  'the primate of england is',
#  'the order of england is',
#  'the peerage of england is',
#  'the president of england is',
#  'the chancellor of england is',
#  'the kingdom of thailand is',
#  'the primate of thailand is',
#  'the constitution of taiwan is',
#  'the constitution of korea is',
#  'the primate of sweden is',
#  'the monarch of sweden is',
#  'the constitution of portugal is',
#  'the parliament of portugal is',
#  'the primate of portugal is',
#  'the president of iraq is',
#  'the constitution of iraq is',
#  'the king of iraq is',
#  'the sultan of iraq is',
#  'the queen of iraq is',
#  'the cabinet of iraq is',
#  'the kingdom of iraq is',
#  'the primate of iraq is',
#  'the chancellor of iraq is',
#  'the emir of iraq is',
#  'the constitution of colombia is',
#  'the economy of colombia is',
#  'the nation of colombia is',
#  'the anthem of colombia is',
#  'the constitution of malaysia is',
#  'the kingdom of malaysia is',
#  'the monarch of malaysia is',
#  'the parliament of denmark is',
#  'the constitution of ireland is',
#  'the primate of ireland is',
#  'the senate of ireland is',
#  'the president of nigeria is',
#  'the constitution of nigeria is',
#  'the currency of nigeria is',
#  'the primate of nigeria is',
#  'the governor of nigeria is',
#  'the sultan of nigeria is',
#  'the queen of nigeria is',
#  'the kingdom of nigeria is',
#  'the flag of paraguay is',
#  'the constitution of paraguay is',
#  'the capital of paraguay is',
#  'the country of paraguay is',
#  'the anthem of paraguay is',
#  'the constitution of chile is',
#  'the parliament of chile is',
#  'the republic of chile is',
#  'the university of chile is',
#  'the anthem of chile is',
#  'the constitution of venezuela is',
#  'the republic of venezuela is',
#  'the primate of venezuela is',
#  'the president of singapore is',
#  'the governor of singapore is',
#  'the mayor of singapore is',
#  'the archbishop of singapore is',
#  'the chancellor of singapore is',
#  'the government of singapore is',
#  'the constitution of singapore is',
#  'the constitution of austria is',
#  'the chancellor of austria is',
#  'the parliament of austria is',
#  'the primate of austria is',
#  'the queen of austria is',
#  'the parliament of norway is',
#  'the constitution of norway is',
#  'the primate of norway is',
#  'the government of switzerland is',
#  'the continent of europe is',
#  'the atlas of europe is',
#  'the horn of europe is',
#  'the bank of europe is',
#  'the heart of europe is',
#  'the union of europe is',
#  'the constitution of cambodia is',
#  'the kingdom of cambodia is',
#  'the primate of cambodia is',
#  'the queen of cambodia is',
#  'the parliament of cambodia is',
#  'the constitution of hungary is',
#  'the parliament of hungary is',
#  'the monarch of hungary is',
#  'the kingdom of romania is',
#  'the voice of america is',
#  'the university of america is',
#  'the order of america is',
#  'the heart of america is',
#  'the star of america is',
#  'the journal of america is',
#  'the constitution of albania is',
#  'the parliament of albania is',
#  'the republic of albania is',
#  'the constitution of uruguay is',
#  'the president of uruguay is',
#  'the currency of uruguay is',
#  'the government of uruguay is',
#  'the capital of uruguay is',
#  'the parliament of uruguay is',
#  'the anthem of uruguay is',
#  'the republic of uruguay is',
#  'the passport of uruguay is',
#  'the country of uruguay is',
#  'the constitution of belgium is',
#  'the parliament of belgium is',
#  'the kingdom of belgium is',
#  'the chancellor of belgium is',
#  'the constitution of cuba is',
#  'the republic of cuba is',
#  'the kingdom of cuba is',
#  'the parliament of cuba is',
#  'the republic of haiti is',
#  'the queen of haiti is',
#  'the parliament of ukraine is',
#  'the anthem of ukraine is',
#  'the primate of ukraine is',
#  'the republic of ukraine is',
#  'the continent of asia is',
#  'the university of asia is',
#  'the flag of asia is',
#  'the bank of asia is',
#  'the voice of asia is',
#  'the horn of asia is',
#  'the council of asia is',
#  'the order of asia is',
#  'the atlas of asia is',
#  'the queen of asia is',
#  'the primate of britain is',
#  'the constitution of britain is',
#  'the tower of britain is',
#  'the constitution of bulgaria is',
#  'the parliament of bulgaria is',
#  'the kingdom of bulgaria is',
#  'the queen of qatar is',
#  'the anthem of nepal is',
#  'the parliament of finland is',
#  'the primate of finland is',
#  'the anthem of finland is',
#  'the flag of ecuador is',
#  'the constitution of ecuador is',
#  'the currency of ecuador is',
#  'the government of ecuador is',
#  'the population of ecuador is',
#  'the language of ecuador is',
#  'the map of ecuador is',
#  'the border of ecuador is',
#  'the primate of ecuador is',
#  'the kingdom of bahrain is',
#  'the parliament of bahrain is',
#  'the language of burma is',
#  'the flora of burma is',
#  'the constitution of burma is',
#  'the constitution of zimbabwe is',
#  'the flag of zimbabwe is',
#  'the parliament of zimbabwe is',
#  'the government of zimbabwe is',
#  'the capital of zimbabwe is',
#  'the state of zimbabwe is',
#  'the king of zimbabwe is',
#  'the kingdom of zimbabwe is',
#  'the republic of zimbabwe is',
#  'the primate of zimbabwe is',
#  'the queen of zimbabwe is',
#  'the sultan of zimbabwe is',
#  'the parliament of scotland is',
#  'the primate of scotland is',
#  'the constitution of scotland is',
#  'the toast of scotland is',
#  'the government of scotland is',
#  'the herald of scotland is',
#  'the minister of scotland is',
#  'the kingdom of morocco is',
#  'the king of ethiopia is',
#  'the constitution of ethiopia is',
#  'the flag of ethiopia is',
#  'the governor of ethiopia is',
#  'the queen of ethiopia is',
#  'the primate of ethiopia is',
#  'the capital of ethiopia is',
#  'the flag of panama is',
#  'the population of panama is',
#  'the constitution of panama is',
#  'the capital of panama is',
#  'the currency of panama is',
#  'the government of panama is',
#  'the province of lebanon is',
#  'the kingdom of lebanon is',
#  'the republic of lebanon is',
#  'the constitution of kuwait is',
#  'the government of kuwait is',
#  'the parliament of kuwait is',
#  'the kingdom of kuwait is',
#  'the prince of kuwait is',
#  'the queen of kuwait is',
#  'the constitution of armenia is',
#  'the parliament of armenia is',
#  'the republic of armenia is',
#  'the constitution of myanmar is',
#  'the flora of myanmar is',
#  'the king of tibet is',
#  'the patriarch of tibet is',
#  'the sultan of tibet is',
#  'the constitution of guatemala is',
#  'the government of guatemala is',
#  'the currency of guatemala is',
#  'the university of guatemala is',
#  'the population of guatemala is',
#  'the country of guatemala is',
#  'the cabinet of guatemala is',
#  'the constitution of belarus is',
#  'the president of fiji is',
#  'the governor of fiji is',
#  'the king of fiji is',
#  'the sultan of fiji is',
#  'the constitution of fiji is',
#  'the government of fiji is',
#  'the queen of fiji is',
#  'the primate of fiji is',
#  'the parliament of fiji is',
#  'the ruler of fiji is',
#  'the constitution of botswana is',
#  'the flag of botswana is',
#  'the capital of botswana is',
#  'the government of botswana is',
#  'the currency of botswana is',
#  'the parliament of botswana is',
#  'the king of botswana is',
#  'the population of botswana is',
#  'the emblem of botswana is',
#  'the embassy of botswana is',
#  'the sultan of botswana is',
#  'the chancellor of botswana is',
#  'the prince of wales is',
#  'the princess of wales is',
#  'the university of wales is',
#  'the peerage of wales is',
#  'the primate of wales is',
#  'the government of wales is',
#  'the kingdom of wales is',
#  'the constitution of wales is',
#  'the principality of wales is',
#  'the parliament of wales is',
#  'the king of wales is',
#  'the archdeacon of wales is',
#  'the flag of wales is',
#  'the queen of wales is',
#  'the chancellor of wales is',
#  'the constitution of uganda is',
#  'the primate of uganda is',
#  'the parliament of uganda is',
#  'the queen of uganda is',
#  'the constitution of nicaragua is',
#  'the primate of nicaragua is',
#  'the sultan of nicaragua is',
#  'the primate of serbia is',
#  'the kingdom of serbia is',
#  'the parliament of serbia is',
#  'the prince of serbia is',
#  'the queen of serbia is',
#  'the capital of hawaii is',
#  'the flag of madagascar is',
#  'the currency of madagascar is',
#  'the primate of madagascar is',
#  'the flag of tanzania is',
#  'the flora of tanzania is',
#  'the capital of tanzania is',
#  'the queen of tonga is',
#  'the sultan of tonga is',
#  'the monarch of tonga is',
#  'the prince of tonga is',
#  'the constitution of estonia is',
#  'the currency of estonia is',
#  'the anthem of estonia is',
#  'the population of estonia is',
#  'the parliament of estonia is',
#  'the economy of estonia is',
#  'the constitution of sudan is',
#  'the kingdom of sudan is',
#  'the primate of sudan is',
#  'the constitution of kenya is',
#  'the queen of kenya is',
#  'the university of kenya is',
#  'the constitution of croatia is',
#  'the kingdom of croatia is',
#  'the parliament of croatia is',
#  'the capital of croatia is',
#  'the king of croatia is',
#  'the republic of croatia is',
#  'the queen of croatia is',
#  'the passport of croatia is',
#  'the university of usa is',
#  'the voice of usa is',
#  'the queen of usa is',
#  'the constitution of cameroon is',
#  'the republic of cameroon is',
#  'the kingdom of libya is',
#  'the queen of libya is',
#  'the university of georgia is',
#  'the state of georgia is',
#  'the constitution of georgia is',
#  'the republic of georgia is',
#  'the chancellor of georgia is',
#  'the primate of rwanda is',
#  'the queen of rwanda is',
#  'the parliament of rwanda is',
#  'the constitution of philippines is',
#  'the republic of philippines is',
#  'the constitution of somalia is',
#  'the kingdom of somalia is',
#  'the nation of somalia is',
#  'the flag of gabon is',
#  'the constitution of gabon is',
#  'the king of gabon is',
#  'the language of gabon is',
#  'the university of antarctica is',
#  'the coast of antarctica is',
#  'the flag of honduras is',
#  'the constitution of honduras is',
#  'the government of honduras is',
#  'the currency of honduras is',
#  'the king of honduras is',
#  'the parliament of honduras is',
#  'the sultan of honduras is',
#  'the kingdom of yugoslavia is',
#  'the parliament of yugoslavia is',
#  'the queen of yugoslavia is',
#  'the constitution of lithuania is',
#  'the parliament of lithuania is',
#  'the kingdom of lithuania is',
#  'the primate of lithuania is',
#  'the queen of lithuania is',
#  'the monarch of lithuania is',
#  'the republic of benin is',
#  'the kingdom of benin is',
#  'the parliament of slovenia is',
#  'the republic of slovenia is',
#  'the visa of slovenia is',
#  'the queen of bhutan is',
#  'the kingdom of bhutan is',
#  'the constitution of togo is',
#  'the capital of togo is',
#  'the king of togo is',
#  'the president of vanuatu is',
#  'the constitution of vanuatu is',
#  'the flag of vanuatu is',
#  'the parliament of vanuatu is',
#  'the governor of vanuatu is',
#  'the government of vanuatu is',
#  'the sultan of vanuatu is',
#  'the king of vanuatu is',
#  'the currency of vanuatu is',
#  'the republic of vanuatu is',
#  'the cabinet of vanuatu is',
#  'the state of vanuatu is',
#  'the senate of vanuatu is',
#  'the language of vanuatu is',
#  'the republic of macedonia is',
#  'the government of macedonia is',
#  'the kingdom of macedonia is',
#  'the constitution of macedonia is',
#  'the parliament of macedonia is',
#  'the country of macedonia is',
#  'the patriarch of macedonia is',
#  'the constitution of syria is',
#  'the primate of syria is',
#  'the kingdom of syria is',
#  'the constitution of kosovo is',
#  'the parliament of kosovo is',
#  'the republic of kosovo is',
#  'the primate of kosovo is',
#  'the flag of namibia is',
#  'the constitution of namibia is',
#  'the currency of namibia is',
#  'the parliament of namibia is',
#  'the republic of namibia is',
#  'the territory of namibia is',
#  'the city of rome is',
#  'the university of rome is',
#  'the church of rome is',
#  'the archbishop of rome is',
#  'the king of rome is',
#  'the patriarch of rome is',
#  'the constitution of rome is',
#  'the pope of rome is',
#  'the mandate of palestine is',
#  'the population of palestine is',
#  'the parliament of tunisia is',
#  'the kingdom of tunisia is',
#  'the university of beijing is',
#  'the city of beijing is',
#  'the metropolitan of beijing is',
#  'the port of beijing is',
#  'the municipality of beijing is',
#  'the patriarch of beijing is',
#  'the prince of beijing is',
#  'the government of beijing is',
#  'the district of beijing is',
#  'the constitution of greenland is',
#  'the parliament of greenland is',
#  'the flag of zambia is',
#  'the constitution of zambia is',
#  'the king of zambia is',
#  'the queen of zambia is',
#  'the sultan of zambia is',
#  'the primate of zambia is',
#  'the kingdom of zambia is',
#  'the capital of zambia is',
#  'the flag of angola is',
#  'the constitution of angola is',
#  'the currency of angola is',
#  'the population of angola is',
#  'the kingdom of angola is',
#  'the republic of angola is',
#  'the sultan of dubai is',
#  'the king of dubai is',
#  'the prince of dubai is',
#  'the kingdom of persia is',
#  'the shah of persia is',
#  'the prince of persia is',
#  'the queen of persia is',
#  'the constitution of persia is',
#  'the king of prussia is',
#  'the kingdom of prussia is',
#  'the state of prussia is',
#  'the chancellor of prussia is',
#  'the crown of prussia is',
#  'the queen of prussia is',
#  'the government of prussia is',
#  'the queen of oman is',
#  'the constitution of oceania is',
#  'the president of oceania is',
#  'the union of oceania is',
#  'the council of oceania is',
#  'the federation of oceania is',
#  'the government of oceania is',
#  'the balance of oceania is',
#  'the champion of oceania is',
#  'the constitution of jamaica is',
#  'the flag of jamaica is',
#  'the queen of jamaica is',
#  'the republic of mali is',
#  'the arrondissement of paris is',
#  'the university of paris is',
#  'the canton of paris is',
#  'the prefecture of paris is',
#  'the metropolitan of paris is',
#  'the district of paris is',
#  'the commune of paris is',
#  'the sultan of samoa is',
#  'the governor of samoa is',
#  'the king of samoa is',
#  'the parliament of samoa is',
#  'the queen of samoa is',
#  'the primate of samoa is',
#  'the kingdom of yemen is',
#  'the republic of yemen is',
#  'the parliament of yemen is',
#  'the governor of goa is',
#  'the sultan of goa is',
#  'the parliament of goa is',
#  'the constitution of cyprus is',
#  'the constitution of senegal is',
#  'the kingdom of senegal is',
#  'the city of london is',
#  'the university of london is',
#  'the tower of london is',
#  'the museum of london is',
#  'the bishop of london is',
#  'the prince of london is',
#  'the bank of london is',
#  'the duke of london is',
#  'the society of london is',
#  'the college of london is',
#  'the archbishop of london is',
#  'the archbishop of tokyo is',
#  'the metropolitan of tokyo is',
#  'the prince of tokyo is',
#  'the patriarch of tokyo is',
#  'the nation of islam is',
#  'the father of islam is',
#  'the children of earth is',
#  'the heart of earth is',
#  'the people of earth is',
#  'the planet of earth is',
#  'the god of earth is',
#  'the future of earth is',
#  'the king of earth is',
#  'the moon of earth is',
#  'the kingdom of montenegro is']

# %% [markdown]
# ## Фильтрация по схожести предсказаний

# %%
import random

# %%
true_relations = []
for relation in tqdm(relations):
    preds = unmasker(relation + " [MASK].", top_k=5)
    tokens = [pred['token_str'] for pred in preds]
    if preds[0]['score'] > 0.4:
        prompt2 = ' '.join(relation.split(' ')[:3]) + ' ' + random.choice(countries) + ' is [MASK].'
        preds = unmasker(prompt2, top_k=5)
        tokens2 = [pred['token_str'] for pred in preds]
        if len(set(tokens) & set(tokens2)) < 3:
            true_relations.append(relation)
# Out:
# 100%|██████████| 2250/2250 [04:57<00:00,  7.56it/s]

# %%
true_relations
# Out:
# ['the capital of china is',
#  'the treasurer of australia is',
#  'the anthem of russia is',
#  'the capital of russia is',
#  'the capital of argentina is',
#  'the language of argentina is',
#  'the capital of france is',
#  'the currency of france is',
#  'the currency of germany is',
#  'the president of mexico is',
#  'the treasurer of canada is',
#  'the premier of canada is',
#  'the capital of peru is',
#  'the language of peru is',
#  'the economy of peru is',
#  'the president of indonesia is',
#  'the cabinet of indonesia is',
#  'the currency of indonesia is',
#  'the capital of iran is',
#  'the capital of egypt is',
#  'the capital of afghanistan is',
#  'the capital of bolivia is',
#  'the economy of bolivia is',
#  'the language of bolivia is',
#  'the anthem of bolivia is',
#  'the capital of spain is',
#  'the language of spain is',
#  'the capital of greece is',
#  'the governor of ghana is',
#  'the capital of vietnam is',
#  'the governor of vietnam is',
#  'the parliament of bangladesh is',
#  'the capital of bangladesh is',
#  'the anthem of poland is',
#  'the capital of poland is',
#  'the primate of poland is',
#  'the chancellor of england is',
#  'the capital of thailand is',
#  'the capital of taiwan is',
#  'the capital of korea is',
#  'the primate of sweden is',
#  'the governor of sweden is',
#  'the treasurer of sweden is',
#  'the capital of portugal is',
#  'the capital of turkey is',
#  'the anthem of turkey is',
#  'the language of turkey is',
#  'the capital of colombia is',
#  'the language of colombia is',
#  'the capital of denmark is',
#  'the republic of ireland is',
#  'the primate of ireland is',
#  'the capital of nigeria is',
#  'the language of paraguay is',
#  'the president of iceland is',
#  'the capital of iceland is',
#  'the language of mongolia is',
#  'the capital of chile is',
#  'the capital of venezuela is',
#  'the governor of venezuela is',
#  'the university of singapore is',
#  'the capital of austria is',
#  'the capital of norway is',
#  'the capital of switzerland is',
#  'the primate of hungary is',
#  'the capital of hungary is',
#  'the capital of romania is',
#  'the anthem of romania is',
#  'the language of romania is',
#  'the president of albania is',
#  'the anthem of albania is',
#  'the capital of albania is',
#  'the language of albania is',
#  'the capital of uruguay is',
#  'the currency of kazakhstan is',
#  'the capital of cuba is',
#  'the archbishop of haiti is',
#  'the anthem of ukraine is',
#  'the capital of ukraine is',
#  'the capital of bulgaria is',
#  'the anthem of bulgaria is',
#  'the capital of nepal is',
#  'the president of finland is',
#  'the anthem of finland is',
#  'the capital of finland is',
#  'the language of ecuador is',
#  'the language of burma is',
#  'the governor of zimbabwe is',
#  'the capital of morocco is',
#  'the capital of panama is',
#  'the patriarch of lebanon is',
#  'the president of armenia is',
#  'the patriarch of armenia is',
#  'the anthem of armenia is',
#  'the language of myanmar is',
#  'the president of azerbaijan is',
#  'the currency of azerbaijan is',
#  'the capital of azerbaijan is',
#  'the anthem of azerbaijan is',
#  'the language of azerbaijan is',
#  'the language of tibet is',
#  'the president of guatemala is',
#  'the capital of belarus is',
#  'the anthem of belarus is',
#  'the princess of wales is',
#  'the primate of uganda is',
#  'the capital of nicaragua is',
#  'the governor of hawaii is',
#  'the capital of hawaii is',
#  'the economy of tanzania is',
#  'the territory of tanzania is',
#  'the president of malta is',
#  'the primate of malta is',
#  'the president of estonia is',
#  'the anthem of estonia is',
#  'the capital of estonia is',
#  'the language of estonia is',
#  'the economy of estonia is',
#  'the capital of kenya is',
#  'the capital of croatia is',
#  'the governor of cameroon is',
#  'the capital of libya is',
#  'the capital of georgia is',
#  'the capital of algeria is',
#  'the capital of philippines is',
#  'the capital of gabon is',
#  'the language of gabon is',
#  'the university of antarctica is',
#  'the island of antarctica is',
#  'the capital of yugoslavia is',
#  'the anthem of lithuania is',
#  'the governor of benin is',
#  'the language of slovenia is',
#  'the capital of slovenia is',
#  'the anthem of turkmenistan is',
#  'the capital of togo is',
#  'the governor of vanuatu is',
#  'the language of vanuatu is',
#  'the capital of uzbekistan is',
#  'the anthem of uzbekistan is',
#  'the capital of macedonia is',
#  'the territory of macedonia is',
#  'the capital of syria is',
#  'the capital of kosovo is',
#  'the city of rome is',
#  'the governor of palestine is',
#  'the capital of luxembourg is',
#  'the capital of tunisia is',
#  'the university of beijing is',
#  'the city of beijing is',
#  'the president of beijing is',
#  'the island of greenland is',
#  'the territory of greenland is',
#  'the governor of zambia is',
#  'the capital of zambia is',
#  'the economy of angola is',
#  'the language of angola is',
#  'the capital of dubai is',
#  'the city of dubai is',
#  'the capital of prussia is',
#  'the capital of jamaica is',
#  'the capital of mali is',
#  'the university of paris is',
#  'the city of paris is',
#  'the capital of yemen is',
#  'the capital of goa is',
#  'the president of kyrgyzstan is',
#  'the anthem of kyrgyzstan is',
#  'the language of kyrgyzstan is',
#  'the language of senegal is',
#  'the economy of senegal is',
#  'the university of london is',
#  'the tower of london is',
#  'the mayor of london is',
#  'the museum of london is',
#  'the city of tokyo is',
#  'the cathedral of tokyo is',
#  'the language of islam is',
#  'the king of earth is',
#  'the creator of earth is']

# %% [markdown]
# # Отношения для личностей

# %%
persons = ['barack obama', 'elvis presley', 'lewis carroll', 'ernest hemingway', 'thomas edison', 'rihanna', 'bob dylan', 'taylor swift', 
           'anderson cooper', 'friedman']

# %%
import random
import gensim.downloader

# %%
glove_vectors = gensim.downloader.load('glove-twitter-25')
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
all_relations = []
#length = 0
def rec_func(phrases):
    if len(phrases[-1].split(' who ')[1].split(' ')) == 3:
        return
    all_phrases2 = []
    phrases_mask = [phrase[:-1] + ' [MASK].' for phrase in phrases]
    preds = unmasker(phrases_mask, batch_size=32, top_k=10)
    rand_phrases = [random.choice(persons) + ' ,' + phrase.split(',')[1][:-1] + ' [MASK].' for phrase in phrases]
    rand_preds = unmasker(rand_phrases, batch_size=32, top_k=10)
    for ind, pred in enumerate(preds):
        tokens = [var['token_str'] for var in pred[:5]]
        sim = 0
        for token in tokens:
            for token2 in tokens:
                if token in glove_vectors and token2 in glove_vectors:
                    if glove_vectors.similarity(token, token2) > 0.8:
                        sim += 1
        if sim > 15:
            pred_rand = rand_preds[ind]
            tokens_rand = [var['token_str'] for var in pred_rand[:5]]
            if len(set(tokens) & set(tokens_rand)) < 3:
                all_relations.append(pred[0]['sequence'])
            for var in pred:
                all_phrases2.append(var['sequence'])
    return rec_func(all_phrases2)

# %%
preds = unmasker(f"charles dickens, who [MASK].", top_k=100)
phrases = [pred['sequence'] for pred in preds if pred['token_str'][0].isalpha() == True]
relations = rec_func(phrases)
# Out:
# ['charles dickens, who wrote ulysses.',
#  'charles dickens, who read it.',
#  'charles dickens, who plays himself.',
#  'charles dickens, who illustrated it.',
#  'charles dickens, who writes fiction.',
#  'charles dickens, who played himself.',
#  'charles dickens, who knew him.',
#  'charles dickens, who ed hon.',
#  'charles dickens, who acted twice.',
#  'charles dickens, who visited london.',
#  'charles dickens, who reads it.',
#  'charles dickens, who contributed illustrations.',
#  'charles dickens, who knows what.',
#  'charles dickens, who drew him.',
#  'charles dickens, who is blind.',
#  'charles dickens, who actor ).',
#  'charles dickens, who playwrights.',
#  'charles dickens, who jr vol.',
#  'charles dickens, who hunted deer.',
#  'charles dickens, who won twice.',
#  'charles dickens, who novels?.',
#  'charles dickens, who killed himself.',
#  'charles dickens, who fell asleep.',
#  'charles dickens, who laughs again.',
#  'charles dickens, who does it.',
#  'charles dickens, who defied.',
#  'charles dickens, who died recently deceased.',
#  'charles dickens, who lived c c.',
#  'charles dickens, who read shakespeare himself.',
#  'charles dickens, who followed her there.',
#  'charles dickens, who plays himself himself.',
#  'charles dickens, who plays charles dickens.',
#  'charles dickens, who illustrated it himself.',
#  'charles dickens, who illustrated books there.',
#  'charles dickens, who illustrated one book.',
#  'charles dickens, who appeared cz.',
#  'charles dickens, who appeared uncredited ).',
#  'charles dickens, who appears frequently here.',
#  'charles dickens, who trans trans trans.',
#  'charles dickens, who writes himself dickens.',
#  'charles dickens, who works here too.',
#  'charles dickens, who works underground underground.',
#  'charles dickens, who works today hon.',
#  'charles dickens, who played hamlet himself.',
#  'charles dickens, who played charles dickens.',
#  'charles dickens, who played mr hyde.',
#  'charles dickens, who played arthur balfour.',
#  'charles dickens, who married cahill.',
#  'charles dickens, who married mh.',
#  'charles dickens, who follows dickens books.',
#  'charles dickens, who follows dracula himself.',
#  'charles dickens, who follows fortune teller.',
#  'charles dickens, who knew her name.',
#  'charles dickens, who knew that name.',
#  'charles dickens, who voll married.',
#  'charles dickens, who volk wrote.',
#  'charles dickens, who volc is.',
#  'charles dickens, who oppresses.',
#  'charles dickens, who opp ed.',
#  'charles dickens, who oped there.',
#  'charles dickens, who did not appear.',
#  'charles dickens, who did that too.',
#  'charles dickens, who dies young ).',
#  'charles dickens, who dies abroad c.',
#  'charles dickens, who survived young man.',
#  'charles dickens, who ed ed ed.',
#  'charles dickens, who edd wrote.',
#  'charles dickens, who ed dw.',
#  'charles dickens, who himself starred in.',
#  'charles dickens, who himself plays himself.',
#  'charles dickens, who biographers follow.',
#  'charles dickens, who biographer of dickens.',
#  'charles dickens, who biographer ed wood.',
#  'charles dickens, who acted cz.',
#  'charles dickens, who acted in london.',
#  'charles dickens, who acted later on.',
#  'charles dickens, who authored novels.',
#  'charles dickens, who author ed harcourt.',
#  'charles dickens, who authorizes it.',
#  'charles dickens, who laughed again again.',
#  'charles dickens, who novel author ).',
#  'charles dickens, who novel writer ).',
#  'charles dickens, who novelizes himself.',
#  'charles dickens, who novelize novels.',
#  'charles dickens, who reads me dead.',
#  'charles dickens, who painted them himself.',
#  'charles dickens, who translated works c.',
#  'charles dickens, who esques?.',
#  'charles dickens, who esque author.',
#  'charles dickens, who esq ed hon.',
#  'charles dickens, who loved me?.',
#  'charles dickens, who loved you?.',
#  'charles dickens, who loved animals too.',
#  'charles dickens, who biographies me?.',
#  'charles dickens, who illustrators books.',
#  'charles dickens, who illustrator dfc.',
#  'charles dickens, who illustrator character books.',
#  'charles dickens, who contributed verse to.',
#  'charles dickens, who contributed work to.',
#  'charles dickens, who survives young man.',
#  'charles dickens, who knows? p.',
#  'charles dickens, who knows best?.',
#  'charles dickens, who admired his work.',
#  'charles dickens, who is blind himself.',
#  'charles dickens, who is dead now.',
#  'charles dickens, who is jewish himself.',
#  'charles dickens, who is english actor.',
#  'charles dickens, who drowned there too.',
#  'charles dickens, who drowned c..',
#  'charles dickens, who assisted me there.',
#  'charles dickens, who actor played himself.',
#  'charles dickens, who actor plays himself.',
#  'charles dickens, who actor, writer.',
#  'charles dickens, who playwrights?.',
#  'charles dickens, who playwrighted hamlet.',
#  'charles dickens, who playwright writer ).',
#  'charles dickens, who playwright author ).',
#  'charles dickens, who investigates murders here.',
#  'charles dickens, who investigates dracula?.',
#  'charles dickens, who investigates london crime.',
#  'charles dickens, who jrh married.',
#  'charles dickens, who jr. vol.',
#  'charles dickens, who jrs author.',
#  'charles dickens, who jra attended.',
#  'charles dickens, who jry married.',
#  'charles dickens, who succeeded rt hon.',
#  'charles dickens, who hunted dracula?.',
#  'charles dickens, who hunted ghosts?.',
#  'charles dickens, who dirns her.',
#  'charles dickens, who dirces?.',
#  'charles dickens, who doubled in voice.',
#  'charles dickens, who doubled up there.',
#  'charles dickens, who refused employment there.',
#  'charles dickens, who sgtd sgt.',
#  'charles dickens, who sgt pepper played.',
#  'charles dickens, who retired c c.',
#  'charles dickens, who retired home there.',
#  'charles dickens, who retired twice more.',
#  'charles dickens, who retired late c.',
#  'charles dickens, who retired there c.',
#  'charles dickens, who novels about women.',
#  'charles dickens, who killed kate moss.',
#  'charles dickens, who killed frankenstein himself.',
#  'charles dickens, who laughs again!.',
#  'charles dickens, who laughs twice!.',
#  'charles dickens, who narrated me twice.',
#  'charles dickens, who narrated mr hyde.',
#  'charles dickens, who directed mrs robinson.',
#  'charles dickens, who does that?.',
#  'charles dickens, who does so frequently.',
#  'charles dickens, who does nothing wrong.',
#  'charles dickens, who defied censorship.',
#  'charles dickens, who defiled america.',
#  'charles dickens, who deficient himself.',
#  'charles dickens, who deftly writes.',
#  'charles dickens, who inspired it himself.',
#  'charles dickens, who marries mary shelley.',
#  'charles dickens, who marries elizabeth taylor.',
#  'charles dickens, who marries alice cooper.',
#  'charles dickens, who marries helen shaw.',
#  'charles dickens, who marries lucy hale.',
#  'charles dickens, who marries dorothy gale.',
#  'charles dickens, who marries katherine mansfield.',
#  'charles dickens, who volsk vol.',
#  'charles dickens, who volsce vol.',
#  'charles dickens, who volscleston.',
#  'charles dickens, who was blind himself.',
#  'charles dickens, who was american author.',
#  'charles dickens, who was jewish himself.',
#  'charles dickens, who kissed mary shelley.',
#  'charles dickens, who walks on water.',
#  'charles dickens, who worked nearby mt.',
#  'charles dickens, who sang in london.',
#  'charles dickens, who sang part himself.',
#  'charles dickens, who ulysses grant wrote.',
#  'charles dickens, who ulysses loves!.',
#  'charles dickens, who poems himself here.',
#  'charles dickens, who poems poems?.',
#  'charles dickens, who poems hamlet himself.']
